# %%
import pandas as pd

# Specify the correct path to the CSV file
# Example of a relative path (make sure to adjust it according to your directory structure)
df = pd.read_csv("C:/Users/TheCu/OneDrive/covid.csv")

# View the rows
print(df)
# Out:
#       demographic_category                 demographic_value  \
# 0                Age Group                             18-49
# 1                Age Group                               65+
# 2                Age Group                             50-64
# 3                Age Group                             12-17
# 4                Age Group                              5-11
# ...                    ...                               ...
# 28540       Race/Ethnicity                        Other Race
# 28541       Race/Ethnicity  American Indian or Alaska Native
# 28542       Race/Ethnicity                             White
# 28543       Race/Ethnicity                           Unknown
# 28544       Race/Ethnicity                             Asian
#
#       administered_date  total_doses  cumulative_total_doses  \
# 0            2024-09-21         3757                40120572
# 1            2024-09-21         4001                24388267
# ...

# %%
df_data=pd.read_csv('C:/Users/TheCu/OneDrive/covid.csv')

print(df_data.columns.values)
# Out:
# ['demographic_category' 'demographic_value' 'administered_date'
#  'total_doses' 'cumulative_total_doses' 'partially_vaccinated'
#  'total_partially_vaccinated' 'fully_vaccinated'
#  'cumulative_fully_vaccinated' 'at_least_one_dose'
#  'cumulative_at_least_one_dose' 'up_to_date_count'
#  'cumulative_up_to_date_count']

# %%
df.head(11)
# Out:
#    demographic_category demographic_value administered_date  total_doses  \
# 0             Age Group             18-49        2024-09-21         3757
# 1             Age Group               65+        2024-09-21         4001
# 2             Age Group             50-64        2024-09-21         3437
# 3             Age Group             12-17        2024-09-21          757
# 4             Age Group              5-11        2024-09-21          831
# 5             Age Group           Under 5        2024-09-21          433
# 6             Age Group  Unknown Agegroup        2024-09-21            0
# 7                Gender            Female        2024-09-21         7129
# 8                Gender              Male        2024-09-21         6087
# 9        Race/Ethnicity             White        2024-09-21         4906
# 10       Race/Ethnicity            Latino        2024-09-21         1689
#
#     cumulative_total_doses  partially_vaccinated  total_partially_vaccinated  \
# ...

# %%
df.tail(11)
# Out:
#       demographic_category                          demographic_value  \
# 28534            Age Group                                      50-64
# 28535               Gender                                       Male
# 28536       Race/Ethnicity                                     Latino
# 28537       Race/Ethnicity                                Multiracial
# 28538       Race/Ethnicity                  Black or African American
# 28539       Race/Ethnicity  Native Hawaiian or Other Pacific Islander
# 28540       Race/Ethnicity                                 Other Race
# 28541       Race/Ethnicity           American Indian or Alaska Native
# 28542       Race/Ethnicity                                      White
# 28543       Race/Ethnicity                                    Unknown
# 28544       Race/Ethnicity                                      Asian
#
#       administered_date  total_doses  cumulative_total_doses  \
# 28534        2020-01-05            0                       0
# ...

# %%
df.sample(11)
# Out:
#       demographic_category                          demographic_value  \
# 14482            Age Group                           Unknown Agegroup
# 21733            Age Group                                        65+
# 1353             Age Group                                        65+
# 28364       Race/Ethnicity  Native Hawaiian or Other Pacific Islander
# 18535       Race/Ethnicity                                    Unknown
# 11687            Age Group                                      50-64
# 7670             Age Group                           Unknown Agegroup
# 11          Race/Ethnicity                                      Asian
# 12729            Age Group                                      18-49
# 24850            Age Group                                      12-17
# 10116            Age Group                                      50-64
#
#       administered_date  total_doses  cumulative_total_doses  \
# 14482        2022-08-12            1                    3491
# ...

# %%
series_one = pd.Series(df['cumulative_at_least_one_dose']) 
print(series_one) 
print(type(series_one))
# Out:
# 0        15326305
# 1         6431445
# 2         6769732
# 3         2381674
# 4         1539453
#            ...
# 28540           0
# 28541           0
# 28542           0
# 28543           0
# 28544           0
# Name: cumulative_at_least_one_dose, Length: 28545, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
df_data=pd.read_csv('C:/Users/TheCu/OneDrive/covid.csv')

print(df_data.columns.values)
# Out:
# ['demographic_category' 'demographic_value' 'administered_date'
#  'total_doses' 'cumulative_total_doses' 'partially_vaccinated'
#  'total_partially_vaccinated' 'fully_vaccinated'
#  'cumulative_fully_vaccinated' 'at_least_one_dose'
#  'cumulative_at_least_one_dose' 'up_to_date_count'
#  'cumulative_up_to_date_count']

# %%
duplicates_subset = df.duplicated(subset=['demographic_category', 'fully_vaccinated'])

print(duplicates_subset)
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 28540     True
# 28541     True
# 28542     True
# 28543     True
# 28544     True
# Length: 28545, dtype: bool

# %%
num_duplicates_subset = duplicates_subset.sum()

print(num_duplicates_subset)
# Out:
# 21179

# %%
print(f"\nNumber of duplicate rows based on 'demographic_category' and 'fully_vaccinated': {num_duplicates_subset}")
# Out:
# Number of duplicate rows based on 'demographic_category' and 'fully_vaccinated': 21179

# %%
df.drop_duplicates(subset=['fully_vaccinated', 'demographic_category'], keep='last')
# Out:
#       demographic_category demographic_value administered_date  total_doses  \
# 9085                Gender            Female        2023-05-24         6980
# 9310                Gender            Female        2023-05-12         8938
# 9311                Gender              Male        2023-05-12         7727
# 9724             Age Group           Under 5        2023-04-20          536
# 9726                Gender            Female        2023-04-20         5254
# ...                    ...               ...               ...          ...
# 28105               Gender              Male        2020-08-19           22
# 28112       Race/Ethnicity       Multiracial        2020-08-19            3
# 28534            Age Group             50-64        2020-01-05            0
# 28535               Gender              Male        2020-01-05            1
# 28544       Race/Ethnicity             Asian        2020-01-05            0
#
#        cumulative_total_doses  partially_vaccinated  \
# ...

# %%
len('C:/Users/TheCu/OneDrive/covid.csv')
# Out:
# 33

# %%
filtered_df = df[df['demographic_category'] == 'Gender']

print(filtered_df)
# Out:
#       demographic_category         demographic_value administered_date  \
# 7                   Gender                    Female        2024-09-21
# 8                   Gender                      Male        2024-09-21
# 25                  Gender                    Female        2024-09-20
# 26                  Gender                      Male        2024-09-20
# 27                  Gender  Unknown/undifferentiated        2024-09-20
# ...                    ...                       ...               ...
# 28499               Gender                      Male        2020-07-28
# 28500               Gender                    Female        2020-07-28
# 28517               Gender                      Male        2020-07-27
# 28518               Gender                    Female        2020-07-27
# 28535               Gender                      Male        2020-01-05
#
#        total_doses  cumulative_total_doses  partially_vaccinated  \
# ...

# %%
sorted_df_desc = df.sort_values(by='demographic_category', ascending=False)

print(sorted_df)
# Out:
#       demographic_category                          demographic_value  \
# 0                Age Group                                      18-49
# 14669            Age Group                                      12-17
# 14670            Age Group                                       5-11
# 14671            Age Group                                    Under 5
# 14672            Age Group                           Unknown Agegroup
# ...                    ...                                        ...
# 16124       Race/Ethnicity  Native Hawaiian or Other Pacific Islander
# 16125       Race/Ethnicity           American Indian or Alaska Native
# 4625        Race/Ethnicity           American Indian or Alaska Native
# 15984       Race/Ethnicity                                      White
# 28544       Race/Ethnicity                                      Asian
#
#       administered_date  total_doses  cumulative_total_doses  \
# 0            2024-09-21         3757                40120572
# ...

# %%
mean_doses = df['total_doses'].mean()
median_doses = df['total_doses'].median()

print(f"Mean total_doses: {mean_doses}")
print(f"Median total_doses: {median_doses}")
# Out:
# Mean total_doses: 10274.425118234367
# Median total_doses: 1141.0
